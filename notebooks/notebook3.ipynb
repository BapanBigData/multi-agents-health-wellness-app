# %%
from typing import Optional
from urllib.parse import quote_plus
import pymongo
import certifi
from pymongo.errors import ConnectionFailure
from langchain.tools import tool
import os
from dotenv import load_dotenv
import httpx
import asyncio

# Load environment variables
load_dotenv()

# Safe encoding for MongoDB URI
safe_username = quote_plus(os.getenv("MONGO_USERNAME", ""))
safe_password = quote_plus(os.getenv("MONGO_PASSWORD", ""))
MONGO_URI = (
    f"mongodb+srv://{safe_username}:{safe_password}"
    f"@happmongocluster.mongocluster.cosmos.azure.com/"
    f"?tls=true&authMechanism=SCRAM-SHA-256&retrywrites=false&maxIdleTimeMS=120000"
)

DB_NAME = os.getenv("DB_NAME")
COLLECTION_NAME = os.getenv("COLLECTION_NAME")
GEO_KEY = os.getenv("GEOLOCATION_IQ_API_KEY")


async def get_geocode_locationiq(place):
    url = "https://us1.locationiq.com/v1/search.php"
    params = {"key": GEO_KEY, "q": place, "format": "json"}
    async with httpx.AsyncClient() as client:
        res = await client.get(url, params=params)
        data = res.json()
        if data:
            return float(data[0]["lat"]), float(data[0]["lon"])
        return None, None


@tool
async def lookup_provider_info(
    practice_city_name: str,
    primary_taxonomy_description: Optional[str] = None,
    entity_type: str = "Organization",
    npi_number: Optional[int] = None,
    provider_first_name: Optional[str] = None,
    provider_last_name_legal: Optional[str] = None,
    practice_state_name: Optional[str] = None,
    practice_street_address: Optional[str] = None,
    limit: int = 20,
) -> list[dict]:
    """
    Locate healthcare providers or facilities using NPI registry data filtered by location, specialty, or name.

    This tool fetches provider or organization records from a MongoDB collection containing NPPES NPI data.
    It allows filtering by city, state, provider name, taxonomy (specialty), street address, and more.
    The results are further enriched with geographic coordinates (latitude, longitude) using LocationIQ
    for integration with maps or proximity-based queries.

    Args:
        practice_city_name (str): City where the provider or facility is located. (Required)
        primary_taxonomy_description (Optional[str]): Partial match on provider's specialty (e.g., 'cardiology').
        entity_type (str): Either 'Organization' or 'Individual'. Default is 'Organization'.
        npi_number (Optional[int]): Exact NPI number for direct lookup.
        provider_first_name (Optional[str]): First name of the provider (for individuals).
        provider_last_name_legal (Optional[str]): Last name of the provider (for individuals).
        practice_state_name (Optional[str]): State abbreviation (e.g., 'CA', 'NY').
        practice_street_address (Optional[str]): Partial or full street address.
        limit (int): Number of records to return. Default is 20.

    Returns:
        list[dict]: A list of provider/facility records enriched with latitude and longitude, ready for geospatial mapping.
    """

    
    query = {
        "practice_city_name": {"$regex": f"^{practice_city_name.strip()}$", "$options": "i"},
        "entity_type": entity_type
    }

    if npi_number:
        query["npi_number"] = npi_number

    if provider_first_name:
        query["provider_first_name"] = {"$regex": f"^{provider_first_name.strip()}$", "$options": "i"}

    if provider_last_name_legal:
        query["provider_last_name_legal"] = {"$regex": f"^{provider_last_name_legal.strip()}$", "$options": "i"}

    if practice_state_name:
        query["practice_state_name"] = practice_state_name.strip().upper()

    if practice_street_address:
        query["practice_street_address"] = {"$regex": f".*{practice_street_address.strip()}.*", "$options": "i"}

    if primary_taxonomy_description:
        query["primary_taxonomy_description"] = {"$regex": f".*{primary_taxonomy_description.strip()}.*", "$options": "i"}

    try:
        client = pymongo.MongoClient(MONGO_URI, tlsCAFile=certifi.where())
        db = client[DB_NAME]
        collection = db[COLLECTION_NAME]
        print("✅ Connected to MongoDB.")

        raw_results = list(collection.find(query, {"_id": 0}).limit(limit))
        print(f"🔍 Found {len(raw_results)} result(s).")

        enriched_results = []
        for rec in raw_results:
            address = f"{rec.get('practice_street_address', '')}, {rec.get('practice_city_name', '')}, {rec.get('practice_state_name', '')}"
            lat, lon = await get_geocode_locationiq(address)
            rec["latitude"] = lat
            rec["longitude"] = lon
            enriched_results.append(rec)

        return enriched_results

    except ConnectionFailure as conn_fail:
        print(f"❌ MongoDB connection failed. {conn_fail}")
        return []
    except Exception as e:
        print(f"❌ Error: {e}")
        return []
    finally:
        if client:
            client.close()
            print("🔌 MongoDB connection closed.")

# %%
print(lookup_provider_info.description)
# Out:
# Fetch provider details from MongoDB based on filters, with fuzzy search and lat/lon enrichment.
#
# Required:
#     - practice_city_name (str): City where the provider practices.
#
# Optional:
#     - primary_taxonomy_description (str): Fuzzy match against human-readable taxonomy.
#     - entity_type (str): Default is 'Organization'.
#     - npi_number, provider_first_name, provider_last_name_legal, practice_state_name
#     - practice_street_address (partial match allowed)
#     - limit: Number of results to return
#
# Returns:
#     List of dicts with enriched latitude/longitude.

# %%
print(lookup_provider_info.args)
# Out:
# {'practice_city_name': {'title': 'Practice City Name', 'type': 'string'}, 'primary_taxonomy_description': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Primary Taxonomy Description'}, 'entity_type': {'default': 'Organization', 'title': 'Entity Type', 'type': 'string'}, 'npi_number': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'default': None, 'title': 'Npi Number'}, 'provider_first_name': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Provider First Name'}, 'provider_last_name_legal': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Provider Last Name Legal'}, 'practice_state_name': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Practice State Name'}, 'practice_street_address': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Practice Street Address'}, 'limit': {'default': 20, 'title': 'Limit', 'type': 'integer'}}

# %%
query = {
    "practice_city_name": "San Antonio",
    "practice_street_address": "Santa Rosa"
}

response = await lookup_provider_info.ainvoke(query)
# Out:
# C:\Users\Bapan Bairagya\AppData\Local\Temp\ipykernel_16084\2390851473.py:93: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(MONGO_URI, tlsCAFile=certifi.where())
# d:\API Developement\multi_agents_health_wellness_app\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1737: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self._resolve_srv()
# ✅ Connected to MongoDB.
# 🔍 Found 13 result(s).
# 🔌 MongoDB connection closed.

# %%
response
# Out:
# [{'npi_number': 1770768525,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TEJANO EMERGENCY PHYSICIANS PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042880',
#   'taxonomy_codes_list': ['207P00000X'],
#   'primary_taxonomy_code': '207P00000X',
#   'taxonomy_descriptions_list': ['Emergency Medicine'],
#   'primary_taxonomy_description': 'Emergency Medicine',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1023293875,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TEXAS EM-1 MEDICAL SERVICES, PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042880',
#   'taxonomy_codes_list': ['363A00000X', '363L00000X'],
#   'primary_taxonomy_code': '363L00000X',
#   'taxonomy_descriptions_list': ['Physician Assistant', 'Nurse Practitioner'],
#   'primary_taxonomy_description': 'Nurse Practitioner',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1104001957,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TRAVIS EMERGENCY PHYSICIANS PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042190',
#   'taxonomy_codes_list': ['2080P0204X', '208000000X', '207P00000X'],
#   'primary_taxonomy_code': '207P00000X',
#   'taxonomy_descriptions_list': ['Pediatrics - Pediatric Emergency Medicine',
#    'Pediatrics',
#    'Emergency Medicine'],
#   'primary_taxonomy_description': 'Emergency Medicine',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1588849855,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TEXAS EM-1 MEDICAL SERVICES, PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042190',
#   'taxonomy_codes_list': ['363A00000X', '363L00000X'],
#   'primary_taxonomy_code': '363L00000X',
#   'taxonomy_descriptions_list': ['Physician Assistant', 'Nurse Practitioner'],
#   'primary_taxonomy_description': 'Nurse Practitioner',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1568606911,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'RADIOLOGY OF SAN ANTONIO',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042011',
#   'taxonomy_codes_list': ['2085R0202X'],
#   'primary_taxonomy_code': '2085R0202X',
#   'taxonomy_descriptions_list': ['Radiology - Diagnostic Radiology'],
#   'primary_taxonomy_description': 'Radiology - Diagnostic Radiology',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1679871081,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'RIVER CITY IMAGING ASSOCIATES PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA ST',
#   'practice_phone_number': '2107042371',
#   'taxonomy_codes_list': ['261QR0200X', '2085R0202X'],
#   'primary_taxonomy_code': '2085R0202X',
#   'taxonomy_descriptions_list': ['Clinic/Center - Radiology',
#    'Radiology - Diagnostic Radiology'],
#   'primary_taxonomy_description': 'Radiology - Diagnostic Radiology',
#   'latitude': 29.4270933,
#   'longitude': -98.49853160854462},
#  {'npi_number': 1538504873,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'SAFETY SPINE PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 78207,
#   'practice_street_address': '333 NORTH SANTA ROSA STREET',
#   'practice_phone_number': '2107145550',
#   'taxonomy_codes_list': ['204R00000X',
#    '2084N0400X',
#    '246ZE0600X',
#    '2084N0600X'],
#   'primary_taxonomy_code': '2084N0600X',
#   'taxonomy_descriptions_list': ['Electrodiagnostic Medicine',
#    'Psychiatry & Neurology - Neurology',
#    'Specialist/Technologist, Other - Electroneurodiagnostic',
#    'Psychiatry & Neurology - Clinical Neurophysiology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Clinical Neurophysiology',
#   'latitude': 29.4270933,
#   'longitude': -98.49853160854462},
#  {'npi_number': 1285079764,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'BAYLOR COLLEGE OF MEDICINE',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA',
#   'practice_phone_number': '2107043030',
#   'taxonomy_codes_list': ['103K00000X', '170100000X', '208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Behavior Analyst',
#    'Medical Genetics, Ph.D. Medical Genetics',
#    'Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1003381211,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'CHRISTUS SANTA ROSA HEALTH CARE CORPORATION',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA ST',
#   'practice_phone_number': '2107044708',
#   'taxonomy_codes_list': ['231H00000X'],
#   'primary_taxonomy_code': '231H00000X',
#   'taxonomy_descriptions_list': ['Audiologist'],
#   'primary_taxonomy_description': 'Audiologist',
#   'latitude': 29.4270933,
#   'longitude': -98.49853160854462},
#  {'npi_number': 1053377713,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'CITY OF SAN ANTONIO TEXAS',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782074557,
#   'practice_street_address': '315 S SANTA ROSA AVE',
#   'practice_phone_number': '2102077525',
#   'taxonomy_codes_list': ['3416L0300X'],
#   'primary_taxonomy_code': '3416L0300X',
#   'taxonomy_descriptions_list': ['Ambulance - Land Transport'],
#   'primary_taxonomy_description': 'Ambulance - Land Transport',
#   'latitude': 29.422197,
#   'longitude': -98.499247},
#  {'npi_number': 1861415903,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'CHRISTUS SANTA ROSA HEALTH CARE CORPORATION',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA ST',
#   'practice_phone_number': '2107043705',
#   'taxonomy_codes_list': ['261QE0700X'],
#   'primary_taxonomy_code': '261QE0700X',
#   'taxonomy_descriptions_list': ['Clinic/Center - End-Stage Renal Disease (ESRD) Treatment'],
#   'primary_taxonomy_description': 'Clinic/Center - End-Stage Renal Disease (ESRD) Treatment',
#   'latitude': 29.4270933,
#   'longitude': -98.49853160854462},
#  {'npi_number': 1821004151,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'CHRISTUS SANTA ROSA HEALTH CARE CORPORATION',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA ST',
#   'practice_phone_number': '2107043907',
#   'taxonomy_codes_list': ['282N00000X',
#    '1223S0112X',
#    '261QA1903X',
#    '273Y00000X',
#    '282NC2000X'],
#   'primary_taxonomy_code': '282NC2000X',
#   'taxonomy_descriptions_list': ['General Acute Care Hospital',
#    'Dentist - Oral and Maxillofacial Surgery',
#    'Clinic/Center - Ambulatory Surgical',
#    'Rehabilitation Unit',
#    'General Acute Care Hospital - Children'],
#   'primary_taxonomy_description': 'General Acute Care Hospital - Children',
#   'latitude': 29.4270933,
#   'longitude': -98.49853160854462},
#  {'npi_number': 1275712432,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'RICARDO PINERO MD PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA',
#   'practice_phone_number': '2107042742',
#   'taxonomy_codes_list': ['174400000X'],
#   'primary_taxonomy_code': '174400000X',
#   'taxonomy_descriptions_list': ['Specialist'],
#   'primary_taxonomy_description': 'Specialist',
#   'latitude': 29.427025,
#   'longitude': -98.498978}]

# %%
query = {
    "practice_city_name": "San Antonio",
    "practice_street_address": "Santa Rosa",
    "primary_taxonomy_description": "emergency"
}

response1 = await lookup_provider_info.ainvoke(query)
# Out:
# C:\Users\Bapan Bairagya\AppData\Local\Temp\ipykernel_19600\2390851473.py:93: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(MONGO_URI, tlsCAFile=certifi.where())
# d:\API Developement\multi_agents_health_wellness_app\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1737: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self._resolve_srv()
# ✅ Connected to MongoDB.
# 🔍 Found 2 result(s).
# 🔌 MongoDB connection closed.

# %%
response1
# Out:
# [{'npi_number': 1770768525,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TEJANO EMERGENCY PHYSICIANS PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042880',
#   'taxonomy_codes_list': ['207P00000X'],
#   'primary_taxonomy_code': '207P00000X',
#   'taxonomy_descriptions_list': ['Emergency Medicine'],
#   'primary_taxonomy_description': 'Emergency Medicine',
#   'latitude': 29.427025,
#   'longitude': -98.498978},
#  {'npi_number': 1104001957,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TRAVIS EMERGENCY PHYSICIANS PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'SAN ANTONIO',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 782073108,
#   'practice_street_address': '333 N SANTA ROSA AVE',
#   'practice_phone_number': '2107042190',
#   'taxonomy_codes_list': ['2080P0204X', '208000000X', '207P00000X'],
#   'primary_taxonomy_code': '207P00000X',
#   'taxonomy_descriptions_list': ['Pediatrics - Pediatric Emergency Medicine',
#    'Pediatrics',
#    'Emergency Medicine'],
#   'primary_taxonomy_description': 'Emergency Medicine',
#   'latitude': 29.427025,
#   'longitude': -98.498978}]

# %%
query = {
    
    "practice_city_name": "Houston",
    "practice_street_address": "Gessner",
    "primary_taxonomy_description": "emergency"
}

response2 = await lookup_provider_info.ainvoke(query)
# Out:
# C:\Users\Bapan Bairagya\AppData\Local\Temp\ipykernel_19600\2390851473.py:93: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(MONGO_URI, tlsCAFile=certifi.where())
# d:\API Developement\multi_agents_health_wellness_app\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1737: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self._resolve_srv()
# ✅ Connected to MongoDB.
# 🔍 Found 4 result(s).
# 🔌 MongoDB connection closed.

# %%
response2
# Out:
# [{'npi_number': 1629252473,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TRANSCARE, LLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770635139,
#   'practice_street_address': '3300 S GESSNER RD STE 208',
#   'practice_phone_number': '7132668996',
#   'taxonomy_codes_list': ['343900000X'],
#   'primary_taxonomy_code': '343900000X',
#   'taxonomy_descriptions_list': ['Non-emergency Medical Transport (VAN)'],
#   'primary_taxonomy_description': 'Non-emergency Medical Transport (VAN)',
#   'latitude': 29.728584,
#   'longitude': -95.539178},
#  {'npi_number': 1730460569,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'MED-PORT MEDICAL TRANSPORTATION SERVICES',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770742915,
#   'practice_street_address': '8787 S GESSNER DR',
#   'practice_phone_number': '7137770200',
#   'taxonomy_codes_list': ['343900000X'],
#   'primary_taxonomy_code': '343900000X',
#   'taxonomy_descriptions_list': ['Non-emergency Medical Transport (VAN)'],
#   'primary_taxonomy_description': 'Non-emergency Medical Transport (VAN)',
#   'latitude': 29.6861795,
#   'longitude': -95.5286318},
#  {'npi_number': 1295363497,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'MEMORIAL HERMANN HOSPITAL BASED PHYSICIAN GROUP',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770242593,
#   'practice_street_address': '929 GESSNER RD STE 2700',
#   'practice_phone_number': '7132422712',
#   'taxonomy_codes_list': ['208M00000X', '207P00000X'],
#   'primary_taxonomy_code': '207P00000X',
#   'taxonomy_descriptions_list': ['Hospitalist', 'Emergency Medicine'],
#   'primary_taxonomy_description': 'Emergency Medicine',
#   'latitude': 29.7825399,
#   'longitude': -95.5456792},
#  {'npi_number': 1992730246,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'MEMORIAL CITY EMERGENCY PHYSICIANS, LLP',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770242501,
#   'practice_street_address': '921 GESSNER RD',
#   'practice_phone_number': '7132423000',
#   'taxonomy_codes_list': ['363A00000X', '363L00000X', '207P00000X'],
#   'primary_taxonomy_code': '207P00000X',
#   'taxonomy_descriptions_list': ['Physician Assistant',
#    'Nurse Practitioner',
#    'Emergency Medicine'],
#   'primary_taxonomy_description': 'Emergency Medicine',
#   'latitude': 29.78170415,
#   'longitude': -95.54671017208861}]

# %%
query = {
    
    "practice_city_name": "Houston",
    "practice_street_address": "Gessner",
    "primary_taxonomy_description": "Pediatrics"
}

response3 = await lookup_provider_info.ainvoke(query)
# Out:
# C:\Users\Bapan Bairagya\AppData\Local\Temp\ipykernel_19600\2390851473.py:93: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(MONGO_URI, tlsCAFile=certifi.where())
# d:\API Developement\multi_agents_health_wellness_app\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1737: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self._resolve_srv()
# ✅ Connected to MongoDB.
# 🔍 Found 6 result(s).
# 🔌 MongoDB connection closed.

# %%
response3
# Out:
# [{'npi_number': 1538489356,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'JOYCE EGBE, MD. PA.',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770712803,
#   'practice_street_address': '12609 S GESSNER DR',
#   'practice_phone_number': '7137732700',
#   'taxonomy_codes_list': ['208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.6379315,
#   'longitude': -95.5307342},
#  {'npi_number': 1922400043,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'LA PROVIDENCE PEDIATRIC AND FAMILY CLINICS',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770711008,
#   'practice_street_address': '9900 S GESSNER RD',
#   'practice_phone_number': '7139816002',
#   'taxonomy_codes_list': ['208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.8626306,
#   'longitude': -95.5432463},
#  {'npi_number': 1730540832,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'UT PHYSICIANS',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770242658,
#   'practice_street_address': '929B GESSNER RD',
#   'practice_phone_number': '7134861700',
#   'taxonomy_codes_list': ['208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.8626306,
#   'longitude': -95.5432463},
#  {'npi_number': 1528509205,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'UT PHYSICIANS',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770242840,
#   'practice_street_address': '929 GESSNER RD STE 2440',
#   'practice_phone_number': '7134866650',
#   'taxonomy_codes_list': ['208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.7825399,
#   'longitude': -95.5456792},
#  {'npi_number': 1770542458,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'GREAT KIDS PEDIATRICS',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770242527,
#   'practice_street_address': '915 GESSNER RD',
#   'practice_phone_number': '7139326261',
#   'taxonomy_codes_list': ['208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.7801579,
#   'longitude': -95.545028},
#  {'npi_number': 1891884508,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'BLUE FISH PEDIATRICS, L.L.P.',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'HOUSTON',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 770242527,
#   'practice_street_address': '915 GESSNER RD',
#   'practice_phone_number': '7134671741',
#   'taxonomy_codes_list': ['208000000X'],
#   'primary_taxonomy_code': '208000000X',
#   'taxonomy_descriptions_list': ['Pediatrics'],
#   'primary_taxonomy_description': 'Pediatrics',
#   'latitude': 29.7801579,
#   'longitude': -95.545028}]

# %%
query = {
    
    'practice_city_name': "Fort Worth",
    "primary_taxonomy_description": "Neurology"
}

response4 = await lookup_provider_info.ainvoke(query)
# Out:
# C:\Users\Bapan Bairagya\AppData\Local\Temp\ipykernel_16084\2390851473.py:93: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(MONGO_URI, tlsCAFile=certifi.where())
# d:\API Developement\multi_agents_health_wellness_app\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1737: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self._resolve_srv()
# ✅ Connected to MongoDB.
# 🔍 Found 20 result(s).
# 🔌 MongoDB connection closed.

# %%
response4
# Out:
# [{'npi_number': 1851870711,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'MERCY PSYCHIATRY INC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 762444480,
#   'practice_street_address': '4941 GOLDEN TRIANGLE BLVD STE 911',
#   'practice_phone_number': '8177793716',
#   'taxonomy_codes_list': ['2084P0805X'],
#   'primary_taxonomy_code': '2084P0805X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Geriatric Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Geriatric Psychiatry',
#   'latitude': 32.9313795,
#   'longitude': -97.2778235},
#  {'npi_number': 1033699343,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'MENS-SANA TELEPSYCHIATRY PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761232120,
#   'practice_street_address': '5560 MESA SPRINGS DR',
#   'practice_phone_number': '8172924600',
#   'taxonomy_codes_list': ['2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.6398134,
#   'longitude': -97.4128976},
#  {'npi_number': 1912480997,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'HOPE TMS CENTER, LLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761324247,
#   'practice_street_address': '6800 HARRIS PKWY STE 100B',
#   'practice_phone_number': '2816198329',
#   'taxonomy_codes_list': ['2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.6523627,
#   'longitude': -97.4198021},
#  {'npi_number': 1073169470,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TOTALCARE BEHAVIORAL HEALTH',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761044024,
#   'practice_street_address': '1617 W OLEANDER ST STE A',
#   'practice_phone_number': '8179239788',
#   'taxonomy_codes_list': ['2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.7320858,
#   'longitude': -97.3444418},
#  {'npi_number': 1750900478,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'FORT PHYSICIANS & PROFESSIONALS PLLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761323900,
#   'practice_street_address': '5833 OAK BEND TRAIL',
#   'practice_phone_number': '8176787428',
#   'taxonomy_codes_list': ['103K00000X',
#    '2080P0006X',
#    '363LP0808X',
#    '2084P0804X'],
#   'primary_taxonomy_code': '2084P0804X',
#   'taxonomy_descriptions_list': ['Behavior Analyst',
#    'Pediatrics - Developmental - Behavioral Pediatrics',
#    'Nurse Practitioner - Psychiatric/Mental Health',
#    'Psychiatry & Neurology - Child & Adolescent Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Child & Adolescent Psychiatry',
#   'latitude': 32.6669179,
#   'longitude': -97.4008113},
#  {'npi_number': 1710594882,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'SALMON MEDICAL PARTNERS, PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761324106,
#   'practice_street_address': '7213 RED HAWK CT',
#   'practice_phone_number': '8308968080',
#   'taxonomy_codes_list': ['2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.65329925,
#   'longitude': -97.42003167624665},
#  {'npi_number': 1548841349,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'OPEDIA HEALTH LLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761371938,
#   'practice_street_address': '3345 WESTERN CENTER BLVD STE 160',
#   'practice_phone_number': '8173819650',
#   'taxonomy_codes_list': ['2084P2900X', '2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Pain Medicine',
#    'Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.8614755,
#   'longitude': -97.3103883},
#  {'npi_number': 1427629450,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'HANIFA HEALTHCARE PC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761167165,
#   'practice_street_address': '6913 CAMP BOWIE BLVD STE 171',
#   'practice_phone_number': '8177316121',
#   'taxonomy_codes_list': ['2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.7187656,
#   'longitude': -97.4373154},
#  {'npi_number': 1720743982,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'LAVEAR MEDICAL, P.A',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761094874,
#   'practice_street_address': '4055 INTERNATIONAL PLZ STE 660',
#   'practice_phone_number': '8175928427',
#   'taxonomy_codes_list': ['363AM0700X', '2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Physician Assistant - Medical',
#    'Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.6869775,
#   'longitude': -97.3976366},
#  {'npi_number': 1801506191,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'BIG HEART CENTER FOR BRAIN CHANGE',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 762445018,
#   'practice_street_address': '5209 CHATSWORTH LN',
#   'practice_phone_number': '8172019656',
#   'taxonomy_codes_list': ['225100000X', '235Z00000X', '2251N0400X'],
#   'primary_taxonomy_code': '2251N0400X',
#   'taxonomy_descriptions_list': ['Physical Therapist',
#    'Speech-Language Pathologist',
#    'Physical Therapist - Neurology'],
#   'primary_taxonomy_description': 'Physical Therapist - Neurology',
#   'latitude': 32.9232467,
#   'longitude': -97.2713882482362},
#  {'npi_number': 1538937818,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'AMANJI LLC',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 762448514,
#   'practice_street_address': '9908 LAMBERTON TER',
#   'practice_phone_number': '8179805659',
#   'taxonomy_codes_list': ['2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.92078385,
#   'longitude': -97.30344530440317},
#  {'npi_number': 1447244975,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'FT WORTH NEUROLOGY CONSULTANTS PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761044137,
#   'practice_street_address': '1307 8TH AVE',
#   'practice_phone_number': '8179200900',
#   'taxonomy_codes_list': ['2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.730432,
#   'longitude': -97.34326182519416},
#  {'npi_number': 1760459671,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'CLINICAL NEUROSCIENCE PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761044140,
#   'practice_street_address': '1307 8TH AVE STE 608',
#   'practice_phone_number': '8179214191',
#   'taxonomy_codes_list': ['2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.7302844,
#   'longitude': -97.3432566},
#  {'npi_number': 1669423406,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'NEUROLOGY ASSOCIATES OF FORT WORTH',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761042158,
#   'practice_street_address': '1325 PENNSYLVANIA AVE',
#   'practice_phone_number': '8173322876',
#   'taxonomy_codes_list': ['2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.7378593,
#   'longitude': -97.3389416},
#  {'npi_number': 1225080856,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'STEWART KELLER DO PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761024581,
#   'practice_street_address': '1314 LAKE ST',
#   'practice_phone_number': '8173488333',
#   'taxonomy_codes_list': ['2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.7451419,
#   'longitude': -97.3395318},
#  {'npi_number': 1376590422,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'MY HEALTH MY RESOURCES OF TARRANT COUNTY',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761077277,
#   'practice_street_address': '3840 HULEN ST',
#   'practice_phone_number': '8175694395',
#   'taxonomy_codes_list': ['261QC1500X',
#    '261QD1600X',
#    '261QM0801X',
#    '261QM0855X',
#    '261QR0405X',
#    '320900000X',
#    '324500000X',
#    '2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Clinic/Center - Community Health',
#    'Clinic/Center - Developmental Disabilities',
#    'Clinic/Center - Mental Health (Including Community Mental Health Center)',
#    'Clinic/Center - Adolescent and Children Mental Health',
#    'Clinic/Center - Rehabilitation, Substance Use Disorder',
#    'Community Based Residential Treatment Facility, Intellectual and/or Developmental Disabilities',
#    'Substance Abuse Rehabilitation Facility',
#    'Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.721856349999996,
#   'longitude': -97.38835075039916},
#  {'npi_number': 1467559666,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'RICHARD D YENTIS MD FAACP PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761076339,
#   'practice_street_address': '4388 W VICKERY BLVD',
#   'practice_phone_number': '8179888426',
#   'taxonomy_codes_list': ['2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.72362415,
#   'longitude': -97.38293281251538},
#  {'npi_number': 1144328634,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'UNIVERSITY OF NORTH TEXAS HEALTH SCIENCE CENTER AT FORT WORTH',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 76107,
#   'practice_street_address': '855 MONTGOMERY ST',
#   'practice_phone_number': '8177352000',
#   'taxonomy_codes_list': ['103T00000X', '2084P0800X'],
#   'primary_taxonomy_code': '2084P0800X',
#   'taxonomy_descriptions_list': ['Psychologist',
#    'Psychiatry & Neurology - Psychiatry'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Psychiatry',
#   'latitude': 32.75054645,
#   'longitude': -97.36925900376013},
#  {'npi_number': 1033295142,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'EDWARD E ICAZA MD PA',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761323922,
#   'practice_street_address': '5801 OAKBEND TRL STE 270',
#   'practice_phone_number': '8176159496',
#   'taxonomy_codes_list': ['2084N0400X', '2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology',
#    'Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.6653812,
#   'longitude': -97.4163219},
#  {'npi_number': 1558427724,
#   'entity_type': 'Organization',
#   'provider_org_name_legal': 'TEXAS HEALTH CARE, P.L.L.C.',
#   'provider_last_name_legal': nan,
#   'provider_first_name': nan,
#   'practice_city_name': 'FORT WORTH',
#   'practice_state_name': 'TX',
#   'practice_postal_code': 761044142,
#   'practice_street_address': '1307 8TH AVE',
#   'practice_phone_number': '8179246200',
#   'taxonomy_codes_list': ['2084N0400X'],
#   'primary_taxonomy_code': '2084N0400X',
#   'taxonomy_descriptions_list': ['Psychiatry & Neurology - Neurology'],
#   'primary_taxonomy_description': 'Psychiatry & Neurology - Neurology',
#   'latitude': 32.730432,
#   'longitude': -97.34326182519416}]
